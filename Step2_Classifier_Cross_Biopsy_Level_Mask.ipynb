# %%
import os
import cv2
import glob
import ntpath
import random
import warnings
import numpy as np
import pandas as pd
import seaborn as sns

from keras.utils import np_utils 
from keras.models import Model
from keras.optimizers import SGD
from keras.callbacks import LearningRateScheduler,ModelCheckpoint
from keras.metrics import categorical_accuracy, categorical_crossentropy
from keras.layers import Input, Convolution2D, MaxPooling2D, Flatten, Dense, Dropout

warnings.filterwarnings("ignore")

# %%
USE_DROPOUT = False
LEARN_RATE = 0.001
Height = 128
Weight = 128
Channel= 3

# %%
def get_train_holdout_files(current_iteration = 1):
    
    ###############################读取biopsy图像###########################################################
    print("Get train/holdout files.")
        
    src_dir = "D:/jupyter-notebook/LiverCancer/Data_Description/" + str(current_iteration) +"/"

    #分割训练数据和测试数据  
    train_samples = pd.read_csv(src_dir + "train.csv")["file_path"].tolist()
    holdout_samples = pd.read_csv(src_dir + "holdout.csv")["file_path"].tolist()
    print("Train Count: ", len(train_samples), ", Holdout Count: ", len(holdout_samples))
    
    ###############################读取biopsy_mask图像#######################################################
    src_dir = "D:/jupyter-notebook/LiverCancer/Mask_Resized_128/"
    biopsy_masks = []

    for fold in os .listdir(src_dir):
        biopsy_masks = biopsy_masks + [file_path for file_path in glob.glob(src_dir+fold+"/*.jpg")]
        
    print("Mask Full Count: ",len(biopsy_masks))
    
    ##########################################################################################################
    train_mask_samples = []
    holdout_mask_samples = []

    for index, train_sample in enumerate(train_samples):
        temp1 = ntpath.basename(train_sample)
        for index, biopsy_mask in enumerate(biopsy_masks):
            temp2 = ntpath.basename(biopsy_mask)
            if temp1 == temp2:
                train_mask_samples += [biopsy_mask]
                
    for index, holdout_sample in enumerate(holdout_samples):
        temp1 = ntpath.basename(holdout_sample)
        for index, biopsy_mask in enumerate(biopsy_masks):
            temp2 = ntpath.basename(biopsy_mask)
            if temp1 == temp2:
                holdout_mask_samples += [biopsy_mask]
        
    ################################建立描述集合###############################################################
    train_rep = []
    holdout_rep = []
    sets = [[train_rep, train_mask_samples], [holdout_rep, holdout_mask_samples]]

    for set_item in sets:

        rep = set_item[0]
        samples = set_item[1]

        for index, sample_path in enumerate(samples):

            if "grade0" in sample_path:
                sample_label = 0
            elif "grade1" in sample_path:
                sample_label = 1
            elif "grade2" in sample_path:
                sample_label = 2
            elif "grade3" in sample_path:
                sample_label = 3
            elif "grade4" in sample_path:
                sample_label = 4

            rep.append([sample_path, sample_label])

    print("Train Count: ", len(train_rep), ", Holdout Count: ", len(holdout_rep))

    return train_rep, holdout_rep

# %%
def data_generator(batch_size, record_list, train_set):
    
    while True:
        
        batch_index = 0
        image_list = []
        label_list = []

        if train_set:
            random.shuffle(record_list)

        #逐一遍历所有数据
        for index, record_item in enumerate(record_list):

            sample_path = record_item[0]
            sample_label = record_item[1]

            #转换成多分类标签
            sample_label = np_utils.to_categorical(sample_label,5)  

            #读取图片、修改尺寸、标准化
            sample_image = cv2.imread(sample_path)
            sample_image = (sample_image - np.average(sample_image)) / np.std(sample_image)
            sample_image = sample_image.reshape(1, sample_image.shape[0], sample_image.shape[1], 3)

            #数据增强
            if train_set:   
                if random.randint(0, 100) > 50:
                    sample_image = np.fliplr(sample_image)
                if random.randint(0, 100) > 50:
                    sample_image = np.flipud(sample_image)
                if random.randint(0, 100) > 50:
                    sample_image = sample_image[:,::-1]
                if random.randint(0, 100) > 50:
                    sample_image = sample_image[::-1, :]

            #添加数据
            image_list.append(sample_image)
            label_list.append(sample_label)
            batch_index += 1

            if batch_index >= batch_size:
                x = np.vstack(image_list)
                y = np.vstack(label_list)
                yield x, y
                image_list = []
                label_list = []
                batch_index = 0

# %%
train_files, holdout_files = get_train_holdout_files(current_iteration = 1)
# Out:
# Get train/holdout files.
# Train Count:  266 , Holdout Count:  30
# Mask Full Count:  296
# Train Count:  266 , Holdout Count:  30

# %%
def get_net(input_shape=(Height, Weight, Channel), load_weight_path=None) -> Model:  #期待返回类型为model
    
    inputs = Input(shape=input_shape, name="input")
    x = inputs
    x = Convolution2D(32, 3, 3, activation='relu', border_mode='same', name='conv1a', subsample=(1, 1))(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), border_mode='valid', name='pool1')(x)
    if USE_DROPOUT:
        x = Dropout(p=0.3)(x)

    # 2nd layer group
    x = Convolution2D(32, 3, 3, activation='relu', border_mode='same', name='conv2a', subsample=(1, 1))(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), border_mode='valid', name='pool2')(x)
    if USE_DROPOUT:
        x = Dropout(p=0.3)(x)

    # 3rd layer group
    x = Convolution2D(64, 3, 3, activation='relu', border_mode='same', name='conv3b', subsample=(1, 1))(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), border_mode='valid', name='pool3')(x)
    if USE_DROPOUT:
        x = Dropout(p=0.3)(x)

    # 4th layer group
    x = Convolution2D(64, 3, 3, activation='relu', border_mode='same', name='conv4b', subsample=(1, 1),)(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), border_mode='valid', name='pool4')(x)
    if USE_DROPOUT:
        x = Dropout(p=0.3)(x)
        
    # 5th layer group
    x = Convolution2D(128, 3, 3, activation='relu', border_mode='same', name='conv5a', subsample=(1, 1))(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), border_mode='valid', name='pool5')(x)
    if USE_DROPOUT:
        x = Dropout(p=0.3)(x)
        
    # 6th layer group
    x = Convolution2D(128, 3, 3, activation='relu', border_mode='same', name='conv6a', subsample=(1, 1))(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), border_mode='valid', name='pool6')(x)
    if USE_DROPOUT:
        x = Dropout(p=0.3)(x)
        
    # 7th layer group
    x = Convolution2D(256, 3, 3, activation='relu', border_mode='same', name='conv7a', subsample=(1, 1))(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), border_mode='valid', name='pool7')(x)
    if USE_DROPOUT:
        x = Dropout(p=0.3)(x)
        
#     # 8th layer group
#     x = Convolution2D(256, 3, 3, activation='relu', border_mode='same', name='conv8a', subsample=(1, 1))(x)
#     x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), border_mode='valid', name='pool8')(x)
#     if USE_DROPOUT:
#         x = Dropout(p=0.3)(x)
    
    #输出
    x = Flatten()(x)
    x = Dense(64, activation='relu')(x)
    out_class = Dense(5, activation='softmax', name='out_class')(x)

    model = Model(input=inputs, output=out_class)
    
    if load_weight_path is not None:
        model.load_weights(load_weight_path, by_name=False)

    #编译模型
    model.compile(optimizer=SGD(lr=LEARN_RATE, momentum=0.9, nesterov=True), loss={ "out_class": "categorical_crossentropy" }, metrics={"out_class": [categorical_accuracy, categorical_crossentropy] } )
    model.summary(line_length=140)

    return model

# %%
get_net()
# Out:
# ____________________________________________________________________________________________________________________________________________
# Layer (type)                                                   Output Shape                                            Param #
# ============================================================================================================================================
# input (InputLayer)                                             (None, 128, 128, 3)                                     0
# ____________________________________________________________________________________________________________________________________________
# conv1a (Conv2D)                                                (None, 128, 128, 32)                                    896
# ____________________________________________________________________________________________________________________________________________
# pool1 (MaxPooling2D)                                           (None, 64, 64, 32)                                      0
# ____________________________________________________________________________________________________________________________________________
# conv2a (Conv2D)                                                (None, 64, 64, 32)                                      9248
# ____________________________________________________________________________________________________________________________________________
# pool2 (MaxPooling2D)                                           (None, 32, 32, 32)                                      0
# ____________________________________________________________________________________________________________________________________________
# conv3b (Conv2D)                                                (None, 32, 32, 64)                                      18496
# ____________________________________________________________________________________________________________________________________________
# pool3 (MaxPooling2D)                                           (None, 16, 16, 64)                                      0
# ____________________________________________________________________________________________________________________________________________
# conv4b (Conv2D)                                                (None, 16, 16, 64)                                      36928
# ____________________________________________________________________________________________________________________________________________
# pool4 (MaxPooling2D)                                           (None, 8, 8, 64)                                        0
# ____________________________________________________________________________________________________________________________________________
# conv5a (Conv2D)                                                (None, 8, 8, 128)                                       73856
# ____________________________________________________________________________________________________________________________________________
# pool5 (MaxPooling2D)                                           (None, 4, 4, 128)                                       0
# ____________________________________________________________________________________________________________________________________________
# conv6a (Conv2D)                                                (None, 4, 4, 128)                                       147584
# ____________________________________________________________________________________________________________________________________________
# pool6 (MaxPooling2D)                                           (None, 2, 2, 128)                                       0
# ____________________________________________________________________________________________________________________________________________
# conv7a (Conv2D)                                                (None, 2, 2, 256)                                       295168
# ____________________________________________________________________________________________________________________________________________
# pool7 (MaxPooling2D)                                           (None, 1, 1, 256)                                       0
# ____________________________________________________________________________________________________________________________________________
# flatten_1 (Flatten)                                            (None, 256)                                             0
# ____________________________________________________________________________________________________________________________________________
# dense_1 (Dense)                                                (None, 64)                                              16448
# ____________________________________________________________________________________________________________________________________________
# out_class (Dense)                                              (None, 5)                                               325
# ============================================================================================================================================
# Total params: 598,949
# Trainable params: 598,949
# Non-trainable params: 0
# ____________________________________________________________________________________________________________________________________________

# %%
model_name = "liver_CNN"
load_weights_path=None
batch_size = 8

for i in range(10):

    model_name_i =model_name + "_" + str(i+1)
    
    #获得训练和测试集合，以：路径、class label的形式保存
    train_files, holdout_files = get_train_holdout_files( current_iteration = (i+1) )

    #训练数据集
    train_gen = data_generator(batch_size, train_files, train_set=True)

    #测试数据集
    holdout_gen = data_generator(batch_size, holdout_files, train_set=False)

    #动态设置学习率
    learnrate_scheduler = LearningRateScheduler(step_decay)

    #获取model
    model = get_net(load_weight_path=load_weights_path)

    checkpoint = ModelCheckpoint("workdir/model_" + model_name_i + "_"  + "_e" + "{epoch:02d}-{val_loss:.4f}.hd5", monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

    checkpoint_best = ModelCheckpoint("workdir/model_" + model_name_i + "_"  + "_best.hd5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
    
    model.fit_generator(generator=train_gen, samples_per_epoch=len(train_files), nb_epoch=10, verbose=1, validation_data=holdout_gen, nb_val_samples=len(holdout_files), class_weight="auto", callbacks=[checkpoint, checkpoint_best, learnrate_scheduler])

    model.save("workdir/model_" + model_name_i + "_end.hd5")
# Out:
# Get train/holdout files.
# Train Count:  266 , Holdout Count:  30
# Mask Full Count:  296
# Train Count:  266 , Holdout Count:  30
# ____________________________________________________________________________________________________________________________________________
# Layer (type)                                                   Output Shape                                            Param #
# ============================================================================================================================================
# input (InputLayer)                                             (None, 128, 128, 3)                                     0
# ____________________________________________________________________________________________________________________________________________
# conv1a (Conv2D)                                                (None, 128, 128, 32)                                    896
# ____________________________________________________________________________________________________________________________________________
# pool1 (MaxPooling2D)                                           (None, 64, 64, 32)                                      0
# ____________________________________________________________________________________________________________________________________________
# conv2a (Conv2D)                                                (None, 64, 64, 32)                                      9248
# ____________________________________________________________________________________________________________________________________________
# pool2 (MaxPooling2D)                                           (None, 32, 32, 32)                                      0
# ____________________________________________________________________________________________________________________________________________
# conv3b (Conv2D)                                                (None, 32, 32, 64)                                      18496
# ____________________________________________________________________________________________________________________________________________
# pool3 (MaxPooling2D)                                           (None, 16, 16, 64)                                      0
# ____________________________________________________________________________________________________________________________________________
# conv4b (Conv2D)                                                (None, 16, 16, 64)                                      36928
# ____________________________________________________________________________________________________________________________________________
# pool4 (MaxPooling2D)                                           (None, 8, 8, 64)                                        0
# ____________________________________________________________________________________________________________________________________________
# conv5a (Conv2D)                                                (None, 8, 8, 128)                                       73856
# ____________________________________________________________________________________________________________________________________________
# pool5 (MaxPooling2D)                                           (None, 4, 4, 128)                                       0
# ____________________________________________________________________________________________________________________________________________
# conv6a (Conv2D)                                                (None, 4, 4, 128)                                       147584
# ____________________________________________________________________________________________________________________________________________
# pool6 (MaxPooling2D)                                           (None, 2, 2, 128)                                       0
# ____________________________________________________________________________________________________________________________________________
# conv7a (Conv2D)                                                (None, 2, 2, 256)                                       295168
# ____________________________________________________________________________________________________________________________________________
# pool7 (MaxPooling2D)                                           (None, 1, 1, 256)                                       0
# ____________________________________________________________________________________________________________________________________________
# flatten_2 (Flatten)                                            (None, 256)                                             0
# ____________________________________________________________________________________________________________________________________________
# dense_2 (Dense)                                                (None, 64)                                              16448
# ____________________________________________________________________________________________________________________________________________
# out_class (Dense)                                              (None, 5)                                               325
# ============================================================================================================================================
# Total params: 598,949
# Trainable params: 598,949
# Non-trainable params: 0
# ____________________________________________________________________________________________________________________________________________
# Epoch 1/10
# learnrate:  0.001  epoch:  0
# 266/266 [==============================] - 23s 86ms/step - loss: 1.5786 - categorical_accuracy: 0.3055 - categorical_crossentropy: 1.5786 - val_loss: 1.4393 - val_categorical_accuracy: 0.5000 - val_categorical_crossentropy: 1.4393
#
# Epoch 00001: saving model to workdir/model_liver_CNN_1__e01-1.4393.hd5
#
# Epoch 00001: val_loss improved from inf to 1.43926, saving model to workdir/model_liver_CNN_1__best.hd5
# Epoch 2/10
# learnrate:  0.001  epoch:  1
# 266/266 [==============================] - 14s 54ms/step - loss: 1.0394 - categorical_accuracy: 0.5409 - categorical_crossentropy: 1.0394 - val_loss: 0.6997 - val_categorical_accuracy: 0.6250 - val_categorical_crossentropy: 0.6997
#
# Epoch 00002: saving model to workdir/model_liver_CNN_1__e02-0.6997.hd5
#
# Epoch 00002: val_loss improved from 1.43926 to 0.69974, saving model to workdir/model_liver_CNN_1__best.hd5
# Epoch 3/10
# learnrate:  0.001  epoch:  2
# 266/266 [==============================] - 14s 54ms/step - loss: 0.8716 - categorical_accuracy: 0.5968 - categorical_crossentropy: 0.8716 - val_loss: 0.6670 - val_categorical_accuracy: 0.7083 - val_categorical_crossentropy: 0.6670
#
# Epoch 00003: saving model to workdir/model_liver_CNN_1__e03-0.6670.hd5
#
# Epoch 00003: val_loss improved from 0.69974 to 0.66703, saving model to workdir/model_liver_CNN_1__best.hd5
# Epoch 4/10
# learnrate:  0.001  epoch:  3
# 266/266 [==============================] - 14s 52ms/step - loss: 0.7441 - categorical_accuracy: 0.6584 - categorical_crossentropy: 0.7441 - val_loss: 0.5877 - val_categorical_accuracy: 0.7083 - val_categorical_crossentropy: 0.5877
#
# Epoch 00004: saving model to workdir/model_liver_CNN_1__e04-0.5877.hd5
#
# Epoch 00004: val_loss improved from 0.66703 to 0.58766, saving model to workdir/model_liver_CNN_1__best.hd5
# Epoch 5/10
# learnrate:  0.001  epoch:  4
# 266/266 [==============================] - 14s 51ms/step - loss: 0.7211 - categorical_accuracy: 0.6692 - categorical_crossentropy: 0.7211 - val_loss: 0.4790 - val_categorical_accuracy: 0.7917 - val_categorical_crossentropy: 0.4790 - categorical_accuracy: 0.6609 - categorical_crossentrop - ETA: 3s - loss: 0.7310 - categorical_accuracy: 0.6
#
# Epoch 00005: saving model to workdir/model_liver_CNN_1__e05-0.4790.hd5
#
# Epoch 00005: val_loss improved from 0.58766 to 0.47900, saving model to workdir/model_liver_CNN_1__best.hd5
# Epoch 6/10
# learnrate:  0.001  epoch:  5
# 266/266 [==============================] - 11s 42ms/step - loss: 0.6247 - categorical_accuracy: 0.7115 - categorical_crossentropy: 0.6247 - val_loss: 0.4963 - val_categorical_accuracy: 0.7917 - val_categorical_crossentropy: 0.4963
#
# Epoch 00006: saving model to workdir/model_liver_CNN_1__e06-0.4963.hd5
#
# Epoch 00006: val_loss did not improve from 0.47900
# Epoch 7/10
# learnrate:  0.001  epoch:  6
# 266/266 [==============================] - 11s 42ms/step - loss: 0.5669 - categorical_accuracy: 0.7359 - categorical_crossentropy: 0.5669 - val_loss: 0.3909 - val_categorical_accuracy: 0.8333 - val_categorical_crossentropy: 0.3909
#
# Epoch 00007: saving model to workdir/model_liver_CNN_1__e07-0.3909.hd5
#
# Epoch 00007: val_loss improved from 0.47900 to 0.39093, saving model to workdir/model_liver_CNN_1__best.hd5
# Epoch 8/10
# learnrate:  0.001  epoch:  7
# 266/266 [==============================] - 12s 46ms/step - loss: 0.4983 - categorical_accuracy: 0.7829 - categorical_crossentropy: 0.4983 - val_loss: 0.4091 - val_categorical_accuracy: 0.7917 - val_categorical_crossentropy: 0.4091
#
# Epoch 00008: saving model to workdir/model_liver_CNN_1__e08-0.4091.hd5
#
# Epoch 00008: val_loss did not improve from 0.39093
# Epoch 9/10
# learnrate:  0.001  epoch:  8
# 266/266 [==============================] - 13s 48ms/step - loss: 0.4190 - categorical_accuracy: 0.8214 - categorical_crossentropy: 0.4190 - val_loss: 0.4378 - val_categorical_accuracy: 0.7917 - val_categorical_crossentropy: 0.4378
#
# Epoch 00009: saving model to workdir/model_liver_CNN_1__e09-0.4378.hd5
#
# Epoch 00009: val_loss did not improve from 0.39093
# Epoch 10/10
# learnrate:  0.001  epoch:  9
# 266/266 [==============================] - 12s 46ms/step - loss: 0.3259 - categorical_accuracy: 0.8703 - categorical_crossentropy: 0.3259 - val_loss: 0.2287 - val_categorical_accuracy: 0.9167 - val_categorical_crossentropy: 0.2287
#
# Epoch 00010: saving model to workdir/model_liver_CNN_1__e10-0.2287.hd5
#
# Epoch 00010: val_loss improved from 0.39093 to 0.22866, saving model to workdir/model_liver_CNN_1__best.hd5
# Get train/holdout files.
# Train Count:  266 , Holdout Count:  30
# Mask Full Count:  296
# Train Count:  266 , Holdout Count:  30
# ____________________________________________________________________________________________________________________________________________
# Layer (type)                                                   Output Shape                                            Param #
# ============================================================================================================================================
# input (InputLayer)                                             (None, 128, 128, 3)                                     0
# ____________________________________________________________________________________________________________________________________________
# conv1a (Conv2D)                                                (None, 128, 128, 32)                                    896
# ____________________________________________________________________________________________________________________________________________
# pool1 (MaxPooling2D)                                           (None, 64, 64, 32)                                      0
# ____________________________________________________________________________________________________________________________________________
# conv2a (Conv2D)                                                (None, 64, 64, 32)                                      9248
# ____________________________________________________________________________________________________________________________________________
# pool2 (MaxPooling2D)                                           (None, 32, 32, 32)                                      0
# ____________________________________________________________________________________________________________________________________________
# conv3b (Conv2D)                                                (None, 32, 32, 64)                                      18496
# ____________________________________________________________________________________________________________________________________________
# pool3 (MaxPooling2D)                                           (None, 16, 16, 64)                                      0
# ____________________________________________________________________________________________________________________________________________
# conv4b (Conv2D)                                                (None, 16, 16, 64)                                      36928
# ____________________________________________________________________________________________________________________________________________
# pool4 (MaxPooling2D)                                           (None, 8, 8, 64)                                        0
# ____________________________________________________________________________________________________________________________________________
# conv5a (Conv2D)                                                (None, 8, 8, 128)                                       73856
# ____________________________________________________________________________________________________________________________________________
# pool5 (MaxPooling2D)                                           (None, 4, 4, 128)                                       0
# ____________________________________________________________________________________________________________________________________________
# conv6a (Conv2D)                                                (None, 4, 4, 128)                                       147584
# ____________________________________________________________________________________________________________________________________________
# pool6 (MaxPooling2D)                                           (None, 2, 2, 128)                                       0
# ____________________________________________________________________________________________________________________________________________
# conv7a (Conv2D)                                                (None, 2, 2, 256)                                       295168
# ____________________________________________________________________________________________________________________________________________
# pool7 (MaxPooling2D)                                           (None, 1, 1, 256)                                       0
# ____________________________________________________________________________________________________________________________________________
# flatten_3 (Flatten)                                            (None, 256)                                             0
# ____________________________________________________________________________________________________________________________________________
# dense_3 (Dense)                                                (None, 64)                                              16448
# ____________________________________________________________________________________________________________________________________________
# out_class (Dense)                                              (None, 5)                                               325
# ============================================================================================================================================
# Total params: 598,949
# Trainable params: 598,949
# Non-trainable params: 0
# ____________________________________________________________________________________________________________________________________________
# Epoch 1/10
# learnrate:  0.001  epoch:  0
# 266/266 [==============================] - 13s 50ms/step - loss: 1.5371 - categorical_accuracy: 0.3304 - categorical_crossentropy: 1.5371 - val_loss: 1.2191 - val_categorical_accuracy: 0.5000 - val_categorical_crossentropy: 1.2191
# Epoch 00001: saving model to workdir/model_liver_CNN_2__e01-1.2191.hd5
#
# Epoch 00001: val_loss improved from inf to 1.21906, saving model to workdir/model_liver_CNN_2__best.hd5
# Epoch 2/10
# learnrate:  0.001  epoch:  1
# 266/266 [==============================] - 11s 42ms/step - loss: 1.0171 - categorical_accuracy: 0.5390 - categorical_crossentropy: 1.0171 - val_loss: 0.9929 - val_categorical_accuracy: 0.5833 - val_categorical_crossentropy: 0.9929
#
# Epoch 00002: saving model to workdir/model_liver_CNN_2__e02-0.9929.hd5
#
# Epoch 00002: val_loss improved from 1.21906 to 0.99293, saving model to workdir/model_liver_CNN_2__best.hd5
# Epoch 3/10
# learnrate:  0.001  epoch:  2
# 266/266 [==============================] - 11s 42ms/step - loss: 0.8162 - categorical_accuracy: 0.6269 - categorical_crossentropy: 0.8162 - val_loss: 0.6635 - val_categorical_accuracy: 0.6250 - val_categorical_crossentropy: 0.6635
#
# Epoch 00003: saving model to workdir/model_liver_CNN_2__e03-0.6635.hd5
#
# Epoch 00003: val_loss improved from 0.99293 to 0.66353, saving model to workdir/model_liver_CNN_2__best.hd5
# Epoch 4/10
# learnrate:  0.001  epoch:  3
# 266/266 [==============================] - 11s 43ms/step - loss: 0.7328 - categorical_accuracy: 0.6701 - categorical_crossentropy: 0.7328 - val_loss: 0.8550 - val_categorical_accuracy: 0.5417 - val_categorical_crossentropy: 0.8550
#
# Epoch 00004: saving model to workdir/model_liver_CNN_2__e04-0.8550.hd5
#
# Epoch 00004: val_loss did not improve from 0.66353
# Epoch 5/10
# learnrate:  0.001  epoch:  4
# 266/266 [==============================] - 11s 43ms/step - loss: 0.6997 - categorical_accuracy: 0.6960 - categorical_crossentropy: 0.6997 - val_loss: 1.1891 - val_categorical_accuracy: 0.5833 - val_categorical_crossentropy: 1.1891
#
# Epoch 00005: saving model to workdir/model_liver_CNN_2__e05-1.1891.hd5
#
# Epoch 00005: val_loss did not improve from 0.66353
# Epoch 6/10
# learnrate:  0.001  epoch:  5
# 266/266 [==============================] - 11s 43ms/step - loss: 0.6453 - categorical_accuracy: 0.7105 - categorical_crossentropy: 0.6453 - val_loss: 0.7364 - val_categorical_accuracy: 0.6667 - val_categorical_crossentropy: 0.7364
#
# Epoch 00006: saving model to workdir/model_liver_CNN_2__e06-0.7364.hd5
#
# Epoch 00006: val_loss did not improve from 0.66353
# Epoch 7/10
# learnrate:  0.001  epoch:  6
# 266/266 [==============================] - 11s 43ms/step - loss: 0.5908 - categorical_accuracy: 0.7251 - categorical_crossentropy: 0.5908 - val_loss: 0.5692 - val_categorical_accuracy: 0.6667 - val_categorical_crossentropy: 0.5692
#
# Epoch 00007: saving model to workdir/model_liver_CNN_2__e07-0.5692.hd5
#
# Epoch 00007: val_loss improved from 0.66353 to 0.56920, saving model to workdir/model_liver_CNN_2__best.hd5
# Epoch 8/10
# learnrate:  0.001  epoch:  7
# 266/266 [==============================] - 13s 48ms/step - loss: 0.5015 - categorical_accuracy: 0.7627 - categorical_crossentropy: 0.5015 - val_loss: 0.3758 - val_categorical_accuracy: 0.7500 - val_categorical_crossentropy: 0.3758
#
# Epoch 00008: saving model to workdir/model_liver_CNN_2__e08-0.3758.hd5
#
# Epoch 00008: val_loss improved from 0.56920 to 0.37578, saving model to workdir/model_liver_CNN_2__best.hd5
# Epoch 9/10
# learnrate:  0.001  epoch:  8
# 266/266 [==============================] - 13s 48ms/step - loss: 0.4076 - categorical_accuracy: 0.8242 - categorical_crossentropy: 0.4076 - val_loss: 0.3301 - val_categorical_accuracy: 0.7917 - val_categorical_crossentropy: 0.3301
#
# Epoch 00009: saving model to workdir/model_liver_CNN_2__e09-0.3301.hd5
#
# Epoch 00009: val_loss improved from 0.37578 to 0.33006, saving model to workdir/model_liver_CNN_2__best.hd5
# Epoch 10/10
# learnrate:  0.001  epoch:  9
# 266/266 [==============================] - 12s 45ms/step - loss: 0.3744 - categorical_accuracy: 0.8294 - categorical_crossentropy: 0.3744 - val_loss: 0.3112 - val_categorical_accuracy: 0.8333 - val_categorical_crossentropy: 0.3112
#
# Epoch 00010: saving model to workdir/model_liver_CNN_2__e10-0.3112.hd5
#
# Epoch 00010: val_loss improved from 0.33006 to 0.31123, saving model to workdir/model_liver_CNN_2__best.hd5
# Get train/holdout files.
# Train Count:  266 , Holdout Count:  30
# Mask Full Count:  296
# Train Count:  266 , Holdout Count:  30
# ____________________________________________________________________________________________________________________________________________
# Layer (type)                                                   Output Shape                                            Param #
# ============================================================================================================================================
# input (InputLayer)                                             (None, 128, 128, 3)                                     0
# ____________________________________________________________________________________________________________________________________________
# conv1a (Conv2D)                                                (None, 128, 128, 32)                                    896
# ____________________________________________________________________________________________________________________________________________
# pool1 (MaxPooling2D)                                           (None, 64, 64, 32)                                      0
# ____________________________________________________________________________________________________________________________________________
# conv2a (Conv2D)                                                (None, 64, 64, 32)                                      9248
# ____________________________________________________________________________________________________________________________________________
# pool2 (MaxPooling2D)                                           (None, 32, 32, 32)                                      0
# ____________________________________________________________________________________________________________________________________________
# conv3b (Conv2D)                                                (None, 32, 32, 64)                                      18496
# ____________________________________________________________________________________________________________________________________________
# pool3 (MaxPooling2D)                                           (None, 16, 16, 64)                                      0
# ____________________________________________________________________________________________________________________________________________
# conv4b (Conv2D)                                                (None, 16, 16, 64)                                      36928
# ____________________________________________________________________________________________________________________________________________
# pool4 (MaxPooling2D)                                           (None, 8, 8, 64)                                        0
# ____________________________________________________________________________________________________________________________________________
# conv5a (Conv2D)                                                (None, 8, 8, 128)                                       73856
# ____________________________________________________________________________________________________________________________________________
# pool5 (MaxPooling2D)                                           (None, 4, 4, 128)                                       0
# ____________________________________________________________________________________________________________________________________________
# conv6a (Conv2D)                                                (None, 4, 4, 128)                                       147584
# ____________________________________________________________________________________________________________________________________________
# pool6 (MaxPooling2D)                                           (None, 2, 2, 128)                                       0
# ____________________________________________________________________________________________________________________________________________
# conv7a (Conv2D)                                                (None, 2, 2, 256)                                       295168
# ____________________________________________________________________________________________________________________________________________
# pool7 (MaxPooling2D)                                           (None, 1, 1, 256)                                       0
# ____________________________________________________________________________________________________________________________________________
# flatten_4 (Flatten)                                            (None, 256)                                             0
# ____________________________________________________________________________________________________________________________________________
# dense_4 (Dense)                                                (None, 64)                                              16448
# ____________________________________________________________________________________________________________________________________________
# out_class (Dense)                                              (None, 5)                                               325
# ============================================================================================================================================
# Total params: 598,949
# Trainable params: 598,949
# Non-trainable params: 0
# ____________________________________________________________________________________________________________________________________________
# Epoch 1/10
# learnrate:  0.001  epoch:  0
# 266/266 [==============================] - 12s 47ms/step - loss: 1.3935 - categorical_accuracy: 0.4079 - categorical_crossentropy: 1.3935 - val_loss: 1.2426 - val_categorical_accuracy: 0.4167 - val_categorical_crossentropy: 1.2426
#
# Epoch 00001: saving model to workdir/model_liver_CNN_3__e01-1.2426.hd5
#
# Epoch 00001: val_loss improved from inf to 1.24256, saving model to workdir/model_liver_CNN_3__best.hd5
# Epoch 2/10
# learnrate:  0.001  epoch:  1
# 266/266 [==============================] - 11s 42ms/step - loss: 0.8712 - categorical_accuracy: 0.6109 - categorical_crossentropy: 0.8712 - val_loss: 0.8472 - val_categorical_accuracy: 0.5833 - val_categorical_crossentropy: 0.8472
#
# Epoch 00002: saving model to workdir/model_liver_CNN_3__e02-0.8472.hd5
#
# Epoch 00002: val_loss improved from 1.24256 to 0.84724, saving model to workdir/model_liver_CNN_3__best.hd5
# Epoch 3/10
# learnrate:  0.001  epoch:  2
# 266/266 [==============================] - 11s 42ms/step - loss: 0.7689 - categorical_accuracy: 0.6579 - categorical_crossentropy: 0.7689 - val_loss: 1.0537 - val_categorical_accuracy: 0.4167 - val_categorical_crossentropy: 1.0537
#
# Epoch 00003: saving model to workdir/model_liver_CNN_3__e03-1.0537.hd5
#
# Epoch 00003: val_loss did not improve from 0.84724
# Epoch 4/10
# learnrate:  0.001  epoch:  3
# 191/266 [====================>.........] - ETA: 2s - loss: 0.6975 - categorical_accuracy: 0.6957 - categorical_crossentropy: 0.6975
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-6a00a5fcc140> in <module>
#      26     checkpoint_best = ModelCheckpoint("workdir/model_" + model_name_i + "_"  + "_best.hd5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
#      27
# ---> 28     model.fit_generator(generator=train_gen, samples_per_epoch=len(train_files), nb_epoch=10, verbose=1, validation_data=holdout_gen, nb_val_samples=len(holdout_files), class_weight="auto", callbacks=[checkpoint, checkpoint_best, learnrate_scheduler])
#      29
#      30     model.save("workdir/model_" + model_name_i + "_end.hd5")
#
# D:\Anaconda3\envs\my_keras\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# D:\Anaconda3\envs\my_keras\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1424             use_multiprocessing=use_multiprocessing,
#    1425             shuffle=shuffle,
# -> 1426             initial_epoch=initial_epoch)
#    1427
#    1428     @interfaces.legacy_generator_methods_support
#
# D:\Anaconda3\envs\my_keras\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     153             batch_index = 0
#     154             while steps_done < steps_per_epoch:
# --> 155                 generator_output = next(output_generator)
#     156
#     157                 if not hasattr(generator_output, '__len__'):
#
# D:\Anaconda3\envs\my_keras\lib\site-packages\keras\utils\data_utils.py in get(self)
#     785                     raise StopIteration()
#     786                 else:
# --> 787                     time.sleep(self.wait_time)
#     788
#     789         # Make sure to rethrow the first exception in the queue, if any
#
# KeyboardInterrupt:

# %%
def step_decay(epoch):
    res = 0.001
    if epoch > 100:
        res = 0.0001
    print("learnrate: ", res, " epoch: ", epoch)
    return res
