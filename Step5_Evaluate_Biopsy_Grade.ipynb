# %%
import numpy as np
import pandas as pd
from collections import Counter

# %%
df_1 = pd.read_csv("D:/jupyter-notebook/LiverCancer/Predict_Result/nuclei_level_result_5/1_result.csv")
df_2 = pd.read_csv("D:/jupyter-notebook/LiverCancer/Predict_Result/nuclei_level_result_5/2_result.csv")
df_3 = pd.read_csv("D:/jupyter-notebook/LiverCancer/Predict_Result/nuclei_level_result_5/3_result.csv")
df_4 = pd.read_csv("D:/jupyter-notebook/LiverCancer/Predict_Result/nuclei_level_result_5/4_result.csv")
#df_4 = pd.read_csv("D:/jupyter-notebook/LiverCancer/Predict_Result/4_result.csv")
df_5 = pd.read_csv("D:/jupyter-notebook/LiverCancer/Predict_Result/nuclei_level_result_5/5_result.csv")
df_6 = pd.read_csv("D:/jupyter-notebook/LiverCancer/Predict_Result/nuclei_level_result_5/6_result.csv")
df_7 = pd.read_csv("D:/jupyter-notebook/LiverCancer/Predict_Result/nuclei_level_result_5/7_result.csv")
df_8 = pd.read_csv("D:/jupyter-notebook/LiverCancer/Predict_Result/nuclei_level_result_5/8_result.csv")
df_9 = pd.read_csv("D:/jupyter-notebook/LiverCancer/Predict_Result/nuclei_level_result_5/9_result.csv")
df_10 = pd.read_csv("D:/jupyter-notebook/LiverCancer/Predict_Result/nuclei_level_result_5/10_result.csv")
df = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10])

# %%
results = []
results_softmax = df.iloc[:,1:6].values.tolist()
for i in range(len(df)):
    
    max_index = results_softmax[i].index(max(results_softmax[i]))
    results.append(max_index)
    
file_paths = df.iloc[:,0].values.tolist()

temp1 = np.array(file_paths)[:].reshape(-1,1)
temp2 = np.array(results)[:].reshape(-1,1)

nuclei = np.hstack((temp1, temp2)).tolist()

# %%
for i in range(10):
    
    current_iteration = i+1

    src_dir = "D:/jupyter-notebook/LiverCancer/Data_Description/" + str(current_iteration) +"/"

    train_biopsy_samples = pd.read_csv(src_dir + "train.csv")["file_path"].tolist()
    holdout_biopsy_samples = pd.read_csv(src_dir + "holdout.csv")["file_path"].tolist()
    print("Train Biopsy Count: ", len(train_biopsy_samples), ", Holdout Biopsy Count: ", len(holdout_biopsy_samples))
    
    ##############################################################################################
    rater_a = []
    rater_b = []

    for index_count, holdout_biopsy_sample in enumerate(holdout_biopsy_samples):

        biopsy_name = holdout_biopsy_sample.split(".jpg")[0][-9:]+".jpg"

        if "grade0" in holdout_biopsy_sample:
            tru_label = 0
        elif "grade1" in holdout_biopsy_sample:
            tru_label = 1
        elif "grade2" in holdout_biopsy_sample:
            tru_label = 2
        elif "grade3" in holdout_biopsy_sample:
            tru_label = 3
        elif "grade4" in holdout_biopsy_sample:
            tru_label = 4

        rater_a +=[int(tru_label)]

        nuclei_label = []
        for index, nucleus in enumerate(nuclei):

            if biopsy_name in nucleus[0]:

                nuclei_label += [int(nucleus[1])]

        counter = Counter(nuclei_label)
        print(str(index_count) + ":  " + str(counter))
        pre_label = counter.most_common()[0][0]

        rater_b += [int(pre_label)]

    ##############################################################################################
    print(src_dir)
    print(rater_a)
    print(rater_b)
    
    temp, conf = quadratic_weighted_kappa(rater_a,rater_b)
# Out:
# Train Biopsy Count:  266 , Holdout Biopsy Count:  30
# 0:  Counter({0: 274})
# 1:  Counter({0: 216})
# 2:  Counter({3: 634})
# 3:  Counter({1: 394})
# 4:  Counter({0: 224})
# 5:  Counter({3: 500})
# 6:  Counter({0: 273})
# 7:  Counter({1: 454})
# 8:  Counter({3: 453})
# 9:  Counter({2: 193})
# 10:  Counter({0: 271})
# 11:  Counter({4: 195})
# 12:  Counter({1: 402})
# 13:  Counter({4: 178})
# 14:  Counter({2: 250, 3: 3})
# 15:  Counter({3: 446})
# 16:  Counter({0: 219})
# 17:  Counter({1: 440})
# 18:  Counter({2: 283})
# 19:  Counter({4: 173})
# 20:  Counter({0: 268})
# 21:  Counter({2: 222})
# 22:  Counter({3: 624})
# 23:  Counter({4: 217})
# 24:  Counter({2: 245, 3: 2, 4: 1, 1: 1})
# 25:  Counter({3: 610})
# 26:  Counter({3: 435})
# 27:  Counter({0: 222})
# 28:  Counter({0: 234})
# 29:  Counter({3: 604})
# D:/jupyter-notebook/LiverCancer/Data_Description/1/
# [0, 0, 3, 1, 0, 3, 0, 1, 3, 2, 0, 4, 1, 4, 2, 3, 0, 1, 2, 4, 0, 2, 3, 4, 2, 3, 3, 0, 0, 3]
# [0, 0, 3, 1, 0, 3, 0, 1, 3, 2, 0, 4, 1, 4, 2, 3, 0, 1, 2, 4, 0, 2, 3, 4, 2, 3, 3, 0, 0, 3]
# [[9, 0, 0, 0, 0], [0, 4, 0, 0, 0], [0, 0, 5, 0, 0], [0, 0, 0, 8, 0], [0, 0, 0, 0, 4]]
# Train Biopsy Count:  266 , Holdout Biopsy Count:  30
# 0:  Counter({4: 169})
# 1:  Counter({0: 281, 1: 1})
# 2:  Counter({2: 272})
# 3:  Counter({3: 276})
# 4:  Counter({2: 217})
# 5:  Counter({4: 173})
# 6:  Counter({1: 392})
# 7:  Counter({2: 264})
# 8:  Counter({4: 195, 3: 1})
# 9:  Counter({4: 192, 3: 3})
# 10:  Counter({0: 215})
# 11:  Counter({0: 217})
# 12:  Counter({4: 192, 2: 3, 3: 2})
# 13:  Counter({0: 195})
# 14:  Counter({3: 509})
# 15:  Counter({1: 421, 0: 1})
# 16:  Counter({2: 270})
# 17:  Counter({0: 291})
# 18:  Counter({0: 217})
# 19:  Counter({3: 289, 4: 14, 2: 4})
# 20:  Counter({1: 349})
# 21:  Counter({3: 472})
# 22:  Counter({0: 209})
# 23:  Counter({0: 257})
# 24:  Counter({2: 251})
# 25:  Counter({4: 207})
# 26:  Counter({1: 417})
# 27:  Counter({0: 198})
# 28:  Counter({1: 393})
# 29:  Counter({2: 268, 3: 4})
# D:/jupyter-notebook/LiverCancer/Data_Description/2/
# [4, 0, 2, 3, 2, 4, 1, 2, 4, 4, 0, 0, 4, 0, 3, 1, 2, 0, 0, 3, 1, 3, 0, 0, 2, 4, 1, 0, 1, 2]
# [4, 0, 2, 3, 2, 4, 1, 2, 4, 4, 0, 0, 4, 0, 3, 1, 2, 0, 0, 3, 1, 3, 0, 0, 2, 4, 1, 0, 1, 2]
# [[9, 0, 0, 0, 0], [0, 5, 0, 0, 0], [0, 0, 6, 0, 0], [0, 0, 0, 4, 0], [0, 0, 0, 0, 6]]
# Train Biopsy Count:  266 , Holdout Biopsy Count:  30
# 0:  Counter({3: 509, 2: 20})
# 1:  Counter({1: 342, 2: 1})
# 2:  Counter({3: 475})
# 3:  Counter({0: 235})
# 4:  Counter({2: 258, 3: 18, 4: 13, 1: 11})
# 5:  Counter({4: 172})
# 6:  Counter({2: 239, 1: 1})
# 7:  Counter({0: 232})
# 8:  Counter({0: 276})
# 9:  Counter({4: 142, 2: 4})
# 10:  Counter({0: 273})
# 11:  Counter({4: 167, 0: 3, 1: 1})
# 12:  Counter({3: 447})
# 13:  Counter({1: 398, 3: 20})
# 14:  Counter({3: 477})
# 15:  Counter({0: 210})
# 16:  Counter({4: 191})
# 17:  Counter({2: 254})
# 18:  Counter({2: 228})
# 19:  Counter({2: 221, 1: 3, 0: 2})
# 20:  Counter({4: 195})
# 21:  Counter({3: 518, 2: 1})
# 22:  Counter({4: 171})
# 23:  Counter({3: 610})
# 24:  Counter({0: 206})
# 25:  Counter({2: 254, 3: 1})
# 26:  Counter({2: 260})
# 27:  Counter({1: 427})
# 28:  Counter({4: 187, 2: 4, 0: 1})
# 29:  Counter({0: 233, 1: 1})
# D:/jupyter-notebook/LiverCancer/Data_Description/3/
# [3, 1, 3, 0, 2, 4, 2, 0, 0, 4, 0, 4, 3, 1, 3, 0, 4, 2, 2, 2, 4, 3, 4, 3, 0, 2, 2, 1, 4, 0]
# [3, 1, 3, 0, 2, 4, 2, 0, 0, 4, 0, 4, 3, 1, 3, 0, 4, 2, 2, 2, 4, 3, 4, 3, 0, 2, 2, 1, 4, 0]
# [[7, 0, 0, 0, 0], [0, 3, 0, 0, 0], [0, 0, 7, 0, 0], [0, 0, 0, 6, 0], [0, 0, 0, 0, 7]]
# Train Biopsy Count:  266 , Holdout Biopsy Count:  30
# 0:  Counter({4: 197})
# 1:  Counter({4: 208, 2: 13, 3: 1})
# 2:  Counter({3: 601})
# 3:  Counter({3: 548, 1: 1})
# 4:  Counter({4: 190})
# 5:  Counter({3: 620, 1: 1})
# 6:  Counter({0: 231})
# 7:  Counter({3: 483, 2: 1})
# 8:  Counter({4: 199, 2: 1})
# 9:  Counter({4: 198, 3: 1})
# 10:  Counter({1: 454})
# 11:  Counter({2: 183, 4: 2, 1: 1})
# 12:  Counter({1: 202, 2: 84, 3: 8, 4: 2, 0: 1})
# 13:  Counter({0: 236})
# 14:  Counter({4: 189})
# 15:  Counter({4: 189, 2: 10})
# 16:  Counter({3: 507})
# 17:  Counter({1: 441})
# 18:  Counter({2: 253})
# 19:  Counter({0: 244})
# 20:  Counter({2: 211, 3: 1})
# 21:  Counter({0: 279})
# 22:  Counter({0: 214, 2: 1})
# 23:  Counter({0: 273})
# 24:  Counter({1: 338, 0: 2})
# 25:  Counter({4: 150, 2: 1})
# 26:  Counter({2: 237})
# 27:  Counter({4: 204, 0: 24, 1: 16, 3: 14})
# 28:  Counter({4: 209})
# 29:  Counter({0: 233})
# D:/jupyter-notebook/LiverCancer/Data_Description/4/
# [4, 4, 3, 3, 4, 3, 0, 3, 4, 4, 1, 2, 1, 0, 4, 4, 3, 1, 2, 0, 2, 0, 0, 0, 1, 4, 2, 2, 4, 0]
# [4, 4, 3, 3, 4, 3, 0, 3, 4, 4, 1, 2, 1, 0, 4, 4, 3, 1, 2, 0, 2, 0, 0, 0, 1, 4, 2, 4, 4, 0]
# [[7, 0, 0, 0, 0], [0, 4, 0, 0, 0], [0, 0, 4, 0, 1], [0, 0, 0, 5, 0], [0, 0, 0, 0, 9]]
# Train Biopsy Count:  266 , Holdout Biopsy Count:  30
# 0:  Counter({2: 206})
# 1:  Counter({0: 295})
# 2:  Counter({3: 457})
# 3:  Counter({0: 287})
# 4:  Counter({0: 257})
# 5:  Counter({2: 180})
# 6:  Counter({1: 383})
# 7:  Counter({3: 572, 2: 23})
# 8:  Counter({2: 209})
# 9:  Counter({1: 377})
# 10:  Counter({3: 237, 2: 8, 4: 5})
# 11:  Counter({2: 305, 1: 2, 3: 1})
# 12:  Counter({2: 258})
# 13:  Counter({4: 190})
# 14:  Counter({3: 266})
# 15:  Counter({1: 497})
# 16:  Counter({3: 188, 1: 22, 2: 10})
# 17:  Counter({0: 272})
# 18:  Counter({1: 283, 2: 4, 0: 2})
# 19:  Counter({0: 224})
# 20:  Counter({2: 319, 1: 3, 3: 2})
# 21:  Counter({2: 198, 4: 6})
# 22:  Counter({4: 173})
# 23:  Counter({1: 356})
# 24:  Counter({3: 615})
# 25:  Counter({0: 274})
# 26:  Counter({0: 250})
# 27:  Counter({3: 442})
# 28:  Counter({1: 335})
# 29:  Counter({1: 488})
# D:/jupyter-notebook/LiverCancer/Data_Description/5/
# [2, 0, 3, 0, 0, 2, 1, 3, 2, 1, 3, 2, 2, 4, 3, 1, 3, 0, 1, 0, 2, 2, 4, 1, 3, 0, 0, 3, 1, 1]
# [2, 0, 3, 0, 0, 2, 1, 3, 2, 1, 3, 2, 2, 4, 3, 1, 3, 0, 1, 0, 2, 2, 4, 1, 3, 0, 0, 3, 1, 1]
# [[7, 0, 0, 0, 0], [0, 7, 0, 0, 0], [0, 0, 7, 0, 0], [0, 0, 0, 7, 0], [0, 0, 0, 0, 2]]
# Train Biopsy Count:  266 , Holdout Biopsy Count:  30
# 0:  Counter({3: 254})
# 1:  Counter({0: 198})
# 2:  Counter({4: 166})
# 3:  Counter({0: 308})
# 4:  Counter({3: 461})
# 5:  Counter({2: 213, 3: 1})
# 6:  Counter({3: 519})
# 7:  Counter({0: 219})
# 8:  Counter({1: 423})
# 9:  Counter({2: 256})
# 10:  Counter({1: 428})
# 11:  Counter({4: 200, 3: 6, 2: 3})
# 12:  Counter({0: 281})
# 13:  Counter({3: 543})
# 14:  Counter({4: 197})
# 15:  Counter({0: 237})
# 16:  Counter({0: 211})
# 17:  Counter({3: 546})
# 18:  Counter({0: 271})
# 19:  Counter({2: 204})
# 20:  Counter({0: 206})
# 21:  Counter({4: 227})
# 22:  Counter({3: 218, 4: 31})
# 23:  Counter({2: 240})
# 24:  Counter({1: 352, 0: 1})
# 25:  Counter({0: 251})
# 26:  Counter({0: 185})
# 27:  Counter({1: 409})
# 28:  Counter({2: 285})
# 29:  Counter({1: 449})
# D:/jupyter-notebook/LiverCancer/Data_Description/6/
# [3, 0, 4, 0, 3, 2, 3, 0, 1, 2, 1, 4, 0, 3, 4, 0, 0, 3, 0, 2, 0, 4, 3, 2, 1, 0, 0, 1, 2, 1]
# [3, 0, 4, 0, 3, 2, 3, 0, 1, 2, 1, 4, 0, 3, 4, 0, 0, 3, 0, 2, 0, 4, 3, 2, 1, 0, 0, 1, 2, 1]
# [[10, 0, 0, 0, 0], [0, 5, 0, 0, 0], [0, 0, 5, 0, 0], [0, 0, 0, 6, 0], [0, 0, 0, 0, 4]]
# Train Biopsy Count:  267 , Holdout Biopsy Count:  29
# 0:  Counter({0: 252})
# 1:  Counter({3: 619})
# 2:  Counter({0: 207})
# 3:  Counter({3: 250, 4: 4, 1: 1})
# 4:  Counter({3: 467, 1: 1})
# 5:  Counter({3: 472})
# 6:  Counter({1: 397, 0: 3})
# 7:  Counter({0: 277})
# 8:  Counter({2: 232, 1: 2, 3: 1, 0: 1})
# 9:  Counter({4: 200})
# 10:  Counter({2: 164, 1: 1, 0: 1})
# 11:  Counter({3: 479, 1: 2})
# 12:  Counter({4: 252})
# 13:  Counter({4: 207})
# 14:  Counter({3: 569})
# 15:  Counter({2: 193})
# 16:  Counter({0: 297})
# 17:  Counter({3: 262})
# 18:  Counter({2: 228})
# 19:  Counter({0: 194})
# 20:  Counter({4: 188})
# 21:  Counter({2: 279})
# 22:  Counter({4: 168, 2: 14})
# 23:  Counter({1: 461})
# 24:  Counter({3: 264, 4: 4, 1: 3, 2: 1})
# 25:  Counter({0: 228})
# 26:  Counter({1: 451})
# 27:  Counter({3: 533, 1: 2})
# 28:  Counter({2: 187})
# D:/jupyter-notebook/LiverCancer/Data_Description/7/
# [0, 3, 0, 3, 3, 3, 1, 0, 2, 4, 2, 3, 4, 4, 3, 2, 0, 3, 2, 0, 4, 2, 4, 1, 3, 0, 1, 3, 2]
# [0, 3, 0, 3, 3, 3, 1, 0, 2, 4, 2, 3, 4, 4, 3, 2, 0, 3, 2, 0, 4, 2, 4, 1, 3, 0, 1, 3, 2]
# [[6, 0, 0, 0, 0], [0, 3, 0, 0, 0], [0, 0, 6, 0, 0], [0, 0, 0, 9, 0], [0, 0, 0, 0, 5]]
# Train Biopsy Count:  267 , Holdout Biopsy Count:  29
# 0:  Counter({0: 281})
# 1:  Counter({3: 453})
# 2:  Counter({3: 615})
# 3:  Counter({3: 408})
# 4:  Counter({2: 257})
# 5:  Counter({2: 225})
# 6:  Counter({0: 249})
# 7:  Counter({4: 176})
# 8:  Counter({1: 407})
# 9:  Counter({1: 429})
# 10:  Counter({4: 176})
# 11:  Counter({0: 233})
# 12:  Counter({2: 212})
# 13:  Counter({0: 243})
# 14:  Counter({3: 606, 2: 1})
# 15:  Counter({4: 192})
# 16:  Counter({4: 200})
# 17:  Counter({2: 264, 3: 28, 4: 14, 1: 2, 0: 1})
# 18:  Counter({4: 211})
# 19:  Counter({0: 180})
# 20:  Counter({3: 443})
# 21:  Counter({0: 254})
# 22:  Counter({2: 195, 0: 1})
# 23:  Counter({2: 265})
# 24:  Counter({1: 445, 3: 5})
# 25:  Counter({1: 429})
# 26:  Counter({4: 202})
# 27:  Counter({1: 317, 2: 9, 0: 8})
# 28:  Counter({0: 247})
# D:/jupyter-notebook/LiverCancer/Data_Description/8/
# [0, 3, 3, 3, 2, 2, 0, 4, 1, 1, 4, 0, 2, 0, 3, 4, 4, 2, 4, 0, 3, 0, 2, 2, 1, 1, 4, 1, 0]
# [0, 3, 3, 3, 2, 2, 0, 4, 1, 1, 4, 0, 2, 0, 3, 4, 4, 2, 4, 0, 3, 0, 2, 2, 1, 1, 4, 1, 0]
# [[7, 0, 0, 0, 0], [0, 5, 0, 0, 0], [0, 0, 6, 0, 0], [0, 0, 0, 5, 0], [0, 0, 0, 0, 6]]
# Train Biopsy Count:  267 , Holdout Biopsy Count:  29
# 0:  Counter({1: 483})
# 1:  Counter({2: 223})
# 2:  Counter({2: 218})
# 3:  Counter({0: 274})
# 4:  Counter({4: 183})
# 5:  Counter({0: 222})
# 6:  Counter({0: 295})
# 7:  Counter({3: 246, 4: 2})
# 8:  Counter({0: 257})
# 9:  Counter({3: 248, 4: 10, 1: 2})
# 10:  Counter({2: 260, 3: 1})
# 11:  Counter({0: 225})
# 12:  Counter({4: 194})
# 13:  Counter({1: 409})
# 14:  Counter({0: 277, 1: 21, 2: 1})
# 15:  Counter({0: 243, 1: 1})
# 16:  Counter({1: 378})
# 17:  Counter({3: 509, 4: 5})
# 18:  Counter({0: 189})
# 19:  Counter({3: 560})
# 20:  Counter({0: 183})
# 21:  Counter({4: 222})
# 22:  Counter({4: 198})
# 23:  Counter({0: 209})
# 24:  Counter({0: 279})
# 25:  Counter({1: 231, 4: 19, 2: 9, 3: 2})
# 26:  Counter({4: 201, 2: 1})
# 27:  Counter({1: 402})
# 28:  Counter({3: 482})
# D:/jupyter-notebook/LiverCancer/Data_Description/9/
# [1, 2, 2, 0, 4, 0, 0, 3, 0, 3, 2, 0, 4, 1, 0, 0, 1, 3, 0, 3, 0, 4, 4, 0, 0, 1, 4, 1, 3]
# [1, 2, 2, 0, 4, 0, 0, 3, 0, 3, 2, 0, 4, 1, 0, 0, 1, 3, 0, 3, 0, 4, 4, 0, 0, 1, 4, 1, 3]
# [[11, 0, 0, 0, 0], [0, 5, 0, 0, 0], [0, 0, 3, 0, 0], [0, 0, 0, 5, 0], [0, 0, 0, 0, 5]]
# Train Biopsy Count:  267 , Holdout Biopsy Count:  29
# 0:  Counter({3: 453})
# 1:  Counter({0: 271})
# 2:  Counter({4: 196, 3: 4})
# 3:  Counter({0: 246})
# 4:  Counter({4: 177})
# 5:  Counter({2: 263})
# 6:  Counter({1: 337, 0: 1})
# 7:  Counter({3: 517})
# 8:  Counter({3: 452})
# 9:  Counter({3: 507})
# 10:  Counter({0: 235})
# 11:  Counter({1: 424})
# 12:  Counter({3: 564})
# 13:  Counter({0: 212})
# 14:  Counter({2: 269})
# 15:  Counter({4: 182})
# 16:  Counter({1: 442})
# 17:  Counter({1: 426, 0: 7})
# 18:  Counter({3: 499})
# 19:  Counter({3: 489})
# 20:  Counter({1: 361})
# 21:  Counter({4: 198})
# 22:  Counter({3: 554})
# 23:  Counter({2: 265, 1: 1, 4: 1})
# 24:  Counter({0: 206})
# 25:  Counter({3: 595})
# 26:  Counter({3: 348})
# 27:  Counter({3: 340})
# 28:  Counter({3: 487})
# D:/jupyter-notebook/LiverCancer/Data_Description/10/
# [3, 0, 4, 0, 4, 2, 1, 3, 3, 3, 0, 1, 3, 0, 2, 4, 1, 1, 3, 3, 1, 4, 3, 2, 0, 3, 3, 3, 3]
# [3, 0, 4, 0, 4, 2, 1, 3, 3, 3, 0, 1, 3, 0, 2, 4, 1, 1, 3, 3, 1, 4, 3, 2, 0, 3, 3, 3, 3]
# [[5, 0, 0, 0, 0], [0, 5, 0, 0, 0], [0, 0, 3, 0, 0], [0, 0, 0, 12, 0], [0, 0, 0, 0, 4]]

# %%
def quadratic_weighted_kappa(rater_a, rater_b, min_rating=None, max_rating=None): 
    
    rater_a = np.array(rater_a, dtype=int) 
    rater_b = np.array(rater_b, dtype=int) 
    
    assert(len(rater_a) == len(rater_b)) 
    
    if min_rating is None:
        min_rating = min(min(rater_a), min(rater_b))
    if max_rating is None:
        max_rating = max(max(rater_a), max(rater_b))
        
    conf_mat = confusion_matrix(rater_a, rater_b, min_rating, max_rating)
    
    print(conf_mat)
    
    num_ratings = len(conf_mat) 
    num_scored_items = float(len(rater_a)) 
    
    hist_rater_a = histogram(rater_a, min_rating, max_rating) 
    hist_rater_b = histogram(rater_b, min_rating, max_rating) 
    
    numerator = 0.0 
    denominator = 0.0 
    
    for i in range(num_ratings): 
        for j in range(num_ratings): 
            
            expected_count = (hist_rater_a[i] * hist_rater_b[j] / num_scored_items) 
            d = pow(i - j, 2.0) / pow(num_ratings - 1, 2.0) 
            numerator += d * conf_mat[i][j] / num_scored_items 
            denominator += d * expected_count / num_scored_items 
            
    return 1.0 - numerator / denominator, conf_mat 

def confusion_matrix(rater_a, rater_b, min_rating=None, max_rating=None):

    assert(len(rater_a) == len(rater_b))

    num_ratings = int(max_rating - min_rating + 1)

    conf_mat = [[0 for i in range(num_ratings)] for j in range(num_ratings)]

    for a, b in zip(rater_a, rater_b):

        conf_mat[a - min_rating][b - min_rating] += 1

    return conf_mat

def histogram(ratings, min_rating=None, max_rating=None):

    num_ratings = int(max_rating - min_rating + 1)

    hist_ratings = [0 for x in range(num_ratings)]

    for r in ratings:

        hist_ratings[r - min_rating] += 1
    
    return hist_ratings
